# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel('energy efficiency.xlsx')

# %%
data.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28

# %%
data.drop('Y2',axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'Y1'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# X1    768 non-null float64
# X2    768 non-null float64
# X3    768 non-null float64
# X4    768 non-null float64
# X5    768 non-null float64
# X6    768 non-null int64
# X7    768 non-null float64
# X8    768 non-null int64
# Y1    768 non-null float64
# dtypes: float64(7), int64(2)
# memory usage: 54.1 KB

# %%
data.describe()
# Out:
#                X1          X2          X3          X4         X5          X6  \
# count  768.000000  768.000000  768.000000  768.000000  768.00000  768.000000
# mean     0.764167  671.708333  318.500000  176.604167    5.25000    3.500000
# std      0.105777   88.086116   43.626481   45.165950    1.75114    1.118763
# min      0.620000  514.500000  245.000000  110.250000    3.50000    2.000000
# 25%      0.682500  606.375000  294.000000  140.875000    3.50000    2.750000
# 50%      0.750000  673.750000  318.500000  183.750000    5.25000    3.500000
# 75%      0.830000  741.125000  343.000000  220.500000    7.00000    4.250000
# max      0.980000  808.500000  416.500000  220.500000    7.00000    5.000000
#
#                X7         X8          Y1
# count  768.000000  768.00000  768.000000
# mean     0.234375    2.81250   22.307195
# std      0.133221    1.55096   10.090204
# min      0.000000    0.00000    6.010000
# 25%      0.100000    1.75000   12.992500
# 50%      0.250000    3.00000   18.950000
# 75%      0.400000    4.00000   31.667500
# max      0.400000    5.00000   43.100000

# %%
data.isnull().sum()
# Out:
# X1    0
# X2    0
# X3    0
# X4    0
# X5    0
# X6    0
# X7    0
# X8    0
# Y1    0
# dtype: int64

# %%
#UNIVARIENT ANALYSIS

# %%
fig, ax = plt.subplots(5,2,figsize=(20,20))
ax = ax.flatten()

for i, col in enumerate(data.columns):
    sns.boxplot(data[col], ax = ax[i])
    
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(5,2,figsize=(20,20))
ax = ax.flatten()

for i, col in enumerate(data.columns):
    sns.distplot(data[col], ax = ax[i])
    
plt.tight_layout()
plt.show()

# %%
#BIVARIENT ANALYSIS

# %%
fig, ax = plt.subplots(5,2,figsize=(20,20))
ax = ax.flatten()

for i, col in enumerate(data.columns):
    sns.scatterplot(data[col],data['Y1'], ax = ax[i])
    
plt.tight_layout()
plt.show()

# %%
#pairplot

# %%
sns.pairplot(data)

# %%
#correlation heatmap

# %%
sns.heatmap(data.corr(),annot=True)

# %%
data.corr()
# Out:
#               X1            X2            X3            X4            X5  \
# X1  1.000000e+00 -9.919015e-01 -2.037817e-01 -8.688234e-01  8.277473e-01
# X2 -9.919015e-01  1.000000e+00  1.955016e-01  8.807195e-01 -8.581477e-01
# X3 -2.037817e-01  1.955016e-01  1.000000e+00 -2.923165e-01  2.809757e-01
# X4 -8.688234e-01  8.807195e-01 -2.923165e-01  1.000000e+00 -9.725122e-01
# X5  8.277473e-01 -8.581477e-01  2.809757e-01 -9.725122e-01  1.000000e+00
# X6  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# X7  1.283986e-17  1.318356e-16 -7.969726e-19 -1.381805e-16  1.861418e-18
# X8  1.764620e-17 -3.558613e-16  0.000000e+00 -1.079129e-16  0.000000e+00
# Y1  6.222719e-01 -6.581199e-01  4.556714e-01 -8.618281e-01  8.894305e-01
#
#           X6            X7            X8        Y1
# X1  0.000000  1.283986e-17  1.764620e-17  0.622272
# X2  0.000000  1.318356e-16 -3.558613e-16 -0.658120
# X3  0.000000 -7.969726e-19  0.000000e+00  0.455671
# X4  0.000000 -1.381805e-16 -1.079129e-16 -0.861828
# X5  0.000000  1.861418e-18  0.000000e+00  0.889430
# X6  1.000000  0.000000e+00  0.000000e+00 -0.002587
# X7  0.000000  1.000000e+00  2.129642e-01  0.269842
# X8  0.000000  2.129642e-01  1.000000e+00  0.087368
# Y1 -0.002587  2.698417e-01  8.736846e-02  1.000000

# %%
#Stastical model building

# %%
X=data.drop('Y1',axis=1)
y=data['Y1']

# %%
import warnings 
warnings.filterwarnings('ignore')
import statsmodels.api as sm

X_constant = sm.add_constant(X)
lin_reg = sm.OLS(y,X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     Y1   R-squared:                       0.916
# Model:                            OLS   Adj. R-squared:                  0.915
# Method:                 Least Squares   F-statistic:                     1187.
# Date:                Sat, 04 Jan 2020   Prob (F-statistic):               0.00
# Time:                        18:09:12   Log-Likelihood:                -1912.5
# No. Observations:                 768   AIC:                             3841.
# Df Residuals:                     760   BIC:                             3878.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         84.0134     19.034      4.414      0.000      46.649     121.378
# X1           -64.7734     10.289     -6.295      0.000     -84.973     -44.574
# X2            -0.0626      0.013     -4.670      0.000      -0.089      -0.036
# X3             0.0361      0.004      9.386      0.000       0.029       0.044
# X4            -0.0494      0.008     -6.569      0.000      -0.064      -0.035
# X5             4.1700      0.338     12.338      0.000       3.506       4.833
# X6            -0.0233      0.095     -0.246      0.805      -0.209       0.163
# X7            19.9327      0.814     24.488      0.000      18.335      21.531
# X8             0.2038      0.070      2.915      0.004       0.067       0.341
# ==============================================================================
# Omnibus:                       18.647   Durbin-Watson:                   0.654
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.707
# Skew:                           0.044   Prob(JB):                     6.49e-09
# Kurtosis:                       4.082   Cond. No.                     2.85e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.61e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
X=data.drop(['X6','Y1'],axis=1)
y=data['Y1']

# %%
X_constant = sm.add_constant(X)
lin_reg = sm.OLS(y,X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     Y1   R-squared:                       0.916
# Model:                            OLS   Adj. R-squared:                  0.916
# Method:                 Least Squares   F-statistic:                     1387.
# Date:                Sat, 04 Jan 2020   Prob (F-statistic):               0.00
# Time:                        18:10:29   Log-Likelihood:                -1912.5
# No. Observations:                 768   AIC:                             3839.
# Df Residuals:                     761   BIC:                             3871.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         83.9318     19.019      4.413      0.000      46.596     121.268
# X1           -64.7734     10.283     -6.299      0.000     -84.960     -44.587
# X2            -0.0626      0.013     -4.673      0.000      -0.089      -0.036
# X3             0.0361      0.004      9.392      0.000       0.029       0.044
# X4            -0.0494      0.008     -6.573      0.000      -0.064      -0.035
# X5             4.1700      0.338     12.345      0.000       3.507       4.833
# X7            19.9327      0.813     24.503      0.000      18.336      21.530
# X8             0.2038      0.070      2.916      0.004       0.067       0.341
# ==============================================================================
# Omnibus:                       18.654   Durbin-Watson:                   0.654
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.739
# Skew:                           0.044   Prob(JB):                     6.38e-09
# Kurtosis:                       4.082   Cond. No.                     2.85e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.62e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
#LINEAR REGRESSION MODEL

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=0)

# %%
def algo(model,X_train,X_test,y_train,y_test):
    model.fit(X_train,y_train)
    print('{} train score:{}'.format(model,model.score(X_train,y_train)))
    print('{} test score:{}'.format(model,model.score(X_test,y_test)))

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
from sklearn.ensemble import RandomForestRegressor
rfr= RandomForestRegressor()

# %%
models=[lr,dt,rfr]
for x in models:
    algo(x,X_train,X_test,y_train,y_test)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) train score:0.9175299120539359
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) test score:0.9120005006143111
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best') train score:0.9989872243587712
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best') test score:0.9974833184418251
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False) train score:0.9988137043698619
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False) test score:0.9973411922600316
